# %% [markdown]
# ### Import Libraries

# %%
from procure_cost_reuse import reDimLumber

# %% [markdown]
# ### Run

# %%
## Run Project 1
re_plan = reDimLumber({"file_name": r'./data_boq.csv',
                        "pjt_name": 'FC Lamar',
                        "data_size": 5})    # 'all' or integer

re_plan.run()
# Out:
# Plain procurement & cost analysis --done
# Cutoff in-the-loop procurement & cost analysis --done
#
#                         plain  reuse
# Material Total          63.12  63.12
# Labor Total             35.20  35.20
# Additional Labor Total   0.00   0.63
# Sum                     98.32  98.95
